# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
np.random.seed(0)
hours_studied = np.random.uniform(0, 10, 100)  
exam_scores = 50 + 5 * hours_studied + np.random.normal(0, 2, 100)

# %%
data = pd.DataFrame({'Hours_Studied': hours_studied, 'Exam_Scores': exam_scores})

# %%
data.isnull().sum()
# Out:
# Hours_Studied    0
# Exam_Scores      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Data Spliting

# %%
x = data[['Hours_Studied']]  # here is a one feature so it called simple linear
y = data['Exam_Scores']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Linear Regression Modeling

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Model Evolution

# %%
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([85.00930514, 55.51094488, 99.19760726, 83.9184434 , 83.72503652,
#        84.47712916, 73.46866759, 66.29944958, 89.96808383, 77.83197183,
#        89.29019814, 63.63015294, 80.63138941, 78.81222959, 66.32871541,
#        71.57891323, 64.54200933, 56.41782515, 78.79277537, 89.09419792])

# %% [markdown]
# # Model Accuracy

# %%
MSE = mean_squared_error(Y_test,Y_pred)
MAE = mean_absolute_error(Y_test,Y_pred)
R2 = r2_score(Y_test,Y_pred)

# %%
print(f'mean_absolute_error : {MAE:.2f}')
print(f'mean_squared_error : {MSE:.2f}')
print(f'r2_score : {R2:.2f}')
# Out:
# mean_absolute_error : 1.60
# mean_squared_error : 3.67
# r2_score : 0.97

# %% [markdown]
# # Visulization

# %%
plt.scatter(X_test,Y_test,color = 'b',label='Simple Linear Regression')
plt.plot(X_test,Y_pred,color='r',linewidth=2)
plt.xlabel('Hours Studied')
plt.ylabel('Exam Scores')
plt.legend()
plt.title('Simple Linear Regression: Hours Studied vs. Exam Scores')
plt.legend()
plt.show()
